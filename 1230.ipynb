# %% [markdown]
# <a href="https://colab.research.google.com/github/howard0217/algorithm/blob/master/1230.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Untitled Diagram.jpg](data:image/jpeg;base64,...)

# %%
#bfs
graph = {
  '1' : ['2','3'],
  '2' : ['4', '5'],
  '3' : ['4','5','6'],
  '4' : ['5'],
  '5' : ['7'],
  '6' : ['7'],
  '7' :[]
}

visited = [] # List to keep track of visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node):
  visited.append(node)
  queue.append(node)

  while queue:
    s = queue.pop(0) 
    print (s, end = " ") 

    for neighbour in graph[s]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)
print("bfs ")
# Driver Code
bfs(visited, graph, '1')
print("\n")
#dfs
visited = set() # Set to keep track of visited nodes.

def dfs(visited, graph, node):
    if node not in visited:
        print (node,end=" ")
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)
print("dfs ")
# Driver Code
dfs(visited, graph, '1')
# Out:
# bfs
# 1 2 3 4 5 6 7
#
# dfs
# 1 2 4 5 7 3 6
